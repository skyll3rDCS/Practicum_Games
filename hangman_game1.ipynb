# %%
import numpy as np 
def main_game():
    words = ['intelligence','transformation','presumption','acknowledged','utility','furthermore','accurate','diversity','attached','recovery','assigned','tapes','motivation','bond','edition','nevertheless','transport','cited','fees','scope','enhanced','incorporated','instructions','subsidiary','input','abstract','ministry','capable','expert','preceding','display','incentive','inhibition','trace','ignored','incidence','estate','cooperative','revealed','index','lecture','discrimination','overseas','explicit','aggregate','gender','underlying','brief','domain','rational','minimum','interval','neutral','migration','flexibility','federal','author','initiatives','allocation','exceed']
    word = np.random.choice(words)
    guess = ['_' for i in range(len(word))]
    guessed=[]
    errors = 0 
    print(' '.join(guess))
    print('If you now the word, type it instead of a letter')
    while '_' in guess:
        letter = input('Letter: ')
        letter = letter.lower()
        if letter in guessed:
            print('You tried this letter')
        elif len(letter)==1 and letter.isalpha():
            if letter in word:
                print("That's the one")
                ind = [i for i, ltr in enumerate(word) if ltr == letter]
                for i in ind:
                    guess[i] = letter
                guessed.append(letter)
                print(' '.join(guess))
            elif errors == 8:
                print('You lost!')
                print(f'The word was: {word}')
                break
            else:
                guessed.append(letter)
                errors+=1
                print(hanger()[-errors])
                print(f'Mistake! Overall: {errors}')
        elif len(letter)==len(word):
            if letter == word:
                print('You won!')
                break
            else:
                print('You lost!')
                print(f'The word was: {word}')
                break
        else: 
            print('Input error! Try again.')
            
def start():
    main_game()
    s = 'Y'
    while s == 'Y':
        s = input('Do you want to play again? Type Y or N ')
        if s == 'Y':
            main_game()
        else: break
        
start()
# Out:
# _ _ _ _ _ _ _ _ _
# If you now the word, type it instead of a letter
# Letter: e
# That's the one
# _ _ e _ e _ _ _ _
# Letter: a
#
#                    --------
#                    |
#                    |
#                    |
#                    |
#                    |
#                   ---
#
# Mistake! Overall: 1
# Letter: r
# That's the one
# _ r e _ e _ _ _ _
# Letter: a
# You tried this letter
# Letter: t
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ---
#
# Mistake! Overall: 2
# Letter: i
# That's the one
# _ r e _ e _ i _ _
# Letter: o
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                   ---
#
# Mistake! Overall: 3
# Letter: n
# That's the one
# _ r e _ e _ i n _
# Letter: g
# That's the one
# _ r e _ e _ i n g
# ...

# %%
def hanger():
    hang_stage = ["""
                   --------
                   |      |
                   |      0
                   |     /|\\
                   |      |
                   |     / \\
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |     \|/
                   |      |
                   |     / 
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |     \|/
                   |      |
                   |      
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |     \|
                   |      |
                   |     
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |     
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      
                   |     
                  ---
                """,
                """
                   --------
                   |      |
                   |      O
                   |    
                   |      
                   |     
                  ---
                """,
                """
                   --------
                   |      |
                   |      
                   |    
                   |      
                   |     
                  ---
                """,
              """
                   --------
                   |
                   |  
                   |
                   | 
                   |
                  ---
              """
    ]
    return hang_stage

# %%
# Out:
# ['s', 't', 'r', 'r', 'e']
